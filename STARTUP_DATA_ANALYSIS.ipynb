# %%
# !nvidia-smi
# Out:
# Mon Jul 19 13:24:39 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
sf = pd.read_csv("/content/gdrive/MyDrive/PROJECTS/14. Startup Project-Case Study/startup_funding.csv",dtype=str)

# %% [markdown]
# ##DATA CLEANING AND PREPROCESSING

# %%
sf["AmountInUSD"].fillna("0",inplace=True)

# %%
sf
# Out:
#        SNo        Date  ... AmountInUSD                            Remarks
# 0        0  01/08/2017  ...   1,300,000                                NaN
# 1        1  02/08/2017  ...           0                                NaN
# 2        2  02/08/2017  ...           0                                NaN
# 3        3  02/08/2017  ...     500,000                                NaN
# 4        4  02/08/2017  ...     850,000                                NaN
# ...    ...         ...  ...         ...                                ...
# 2367  2367  29/01/2015  ...   4,500,000                                NaN
# 2368  2368  29/01/2015  ...     825,000                Govt backed VC Fund
# 2369  2369  30/01/2015  ...   1,500,000                                NaN
# 2370  2370  30/01/2015  ...           0  Strategic Funding, Minority stake
# 2371  2371  31/01/2015  ...     140,000                                NaN
#
# [2372 rows x 10 columns]

# %%
temp_sf = sf.copy()

# %%
sf.fillna("unknown",inplace=True)

# %%
sf.drop("SNo",axis=1,inplace=True)

# %%
def casechange(s):
  return s.lower()

for elt in sf.columns:
  sf[elt]=sf[elt].apply(casechange)

# %%
def removecomma(s):
  t=0
  for e in s:
    if e==',':
      continue
    t = t*10+int(float(e))
  return t
sf["AmountInUSD"]=sf["AmountInUSD"].apply(removecomma)

# %%
sf
# Out:
#             Date  ...                            Remarks
# 0     01/08/2017  ...                            unknown
# 1     02/08/2017  ...                            unknown
# 2     02/08/2017  ...                            unknown
# 3     02/08/2017  ...                            unknown
# 4     02/08/2017  ...                            unknown
# ...          ...  ...                                ...
# 2367  29/01/2015  ...                            unknown
# 2368  29/01/2015  ...                govt backed vc fund
# 2369  30/01/2015  ...                            unknown
# 2370  30/01/2015  ...  strategic funding, minority stake
# 2371  31/01/2015  ...                            unknown
#
# [2372 rows x 9 columns]

# %%
temp_sf = sf.copy()

# %% [markdown]
# ##TREND OF INVESTMENT OVER THE YEARS

# %%
def year(s):
  return s[-4:]

sf["Year"]=sf["Date"].apply(year)

# %%
sf
# Out:
#             Date       StartupName  ...                            Remarks  Year
# 0     01/08/2017          touchkin  ...                            unknown  2017
# 1     02/08/2017           ethinos  ...                            unknown  2017
# 2     02/08/2017      leverage edu  ...                            unknown  2017
# 3     02/08/2017              zepo  ...                            unknown  2017
# 4     02/08/2017      click2clinic  ...                            unknown  2017
# ...          ...               ...  ...                                ...   ...
# 2367  29/01/2015        printvenue  ...                            unknown  2015
# 2368  29/01/2015          graphene  ...                govt backed vc fund  2015
# 2369  30/01/2015    mad street den  ...                            unknown  2015
# 2370  30/01/2015         simplotel  ...  strategic funding, minority stake  2015
# 2371  31/01/2015  couponmachine.in  ...                            unknown  2015
#
# [2372 rows x 10 columns]

# %%
x=sf.value_counts("Year").index
y=sf.value_counts("Year").values

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##TOP CITIES FOR STARTING A STARTUP

# %%
def change(s):
  if(s=="delhi"):
    return "new delhi"
  return s
sf["CityLocation"]=sf["CityLocation"].apply(change)

# %%
def name_break(s):
  temp=""
  for i in range(len(s)):
    if s[i]=='/':
      break
    if s[i]==' ' and s[i+1]=='/':
      break
    temp+=s[i]
  return temp


sf["CityLocation"]=sf["CityLocation"].apply(name_break)

sf
# Out:
#             Date       StartupName  ...                            Remarks  Year
# 0     01/08/2017          touchkin  ...                            unknown  2017
# 1     02/08/2017           ethinos  ...                            unknown  2017
# 2     02/08/2017      leverage edu  ...                            unknown  2017
# 3     02/08/2017              zepo  ...                            unknown  2017
# 4     02/08/2017      click2clinic  ...                            unknown  2017
# ...          ...               ...  ...                                ...   ...
# 2367  29/01/2015        printvenue  ...                            unknown  2015
# 2368  29/01/2015          graphene  ...                govt backed vc fund  2015
# 2369  30/01/2015    mad street den  ...                            unknown  2015
# 2370  30/01/2015         simplotel  ...  strategic funding, minority stake  2015
# 2371  31/01/2015  couponmachine.in  ...                            unknown  2015
#
# [2372 rows x 10 columns]

# %%
a = list(sf.value_counts("CityLocation").index)
b = list(sf.value_counts("CityLocation").values)
i = a.index('unknown')

# %%
x=a[:i]+a[i+1:]
x=x[:10]
y=b[:i]+b[i+1:]
y=y[:10]

# %%
plt.pie(y,labels=x,radius=5)
plt.show()

# %%
for i in range(11):
  if(a[i]=='unknown'):
    continue
  print(a[i]," ",b[i])
# Out:
# bangalore   635
# mumbai   449
# new delhi   389
# gurgaon   241
# pune   91
# noida   79
# hyderabad   77
# chennai   67
# ahmedabad   35
# jaipur   25

# %% [markdown]
# ##ROLE OF CITIES IN RECIEVING FUNDS FOR STARTUPs
#
#
# > CITIES V/S RECIEVING FUNDS

# %%
city_names = a.copy()

# %%
city_fund = dict()
total_fund = sf["AmountInUSD"].sum()
for e in city_names:
  ts = sf[sf["CityLocation"]==e]["AmountInUSD"].sum()
  city_fund[e]=ts
cl = list(city_fund.keys())
cf = list(city_fund.values())
di = {"City":cl,"Fund":cf}
cf = pd.DataFrame(di)
cf["Fund"] = cf["Fund"]*100/total_fund
cf.sort_values("Fund",ascending=False,inplace=True)

# %%
cf.reset_index(drop=True,inplace=True)

# %%
cf["Fund"]= round(cf["Fund"],ndigits=2)
cf
# Out:
#           City   Fund
# 0    bangalore  45.91
# 1    new delhi  15.36
# 2       mumbai  12.84
# 3      gurgaon  11.28
# 4      unknown   6.93
# 5      chennai   2.24
# 6         pune   2.00
# 7    hyderabad   1.06
# 8        noida   0.93
# 9    ahmedabad   0.54
# 10      jaipur   0.19
# 11       india   0.16
# 12  chandigarh   0.14
# 13         usa   0.09
# 14     kolkata   0.08
# 15       udupi   0.07
# 16    vadodara   0.03
# 17   singapore   0.02
# 18      boston   0.02
# 19          us   0.02
# 20    new york   0.02
# 21         sfo   0.01
# 22         goa   0.01
# 23      bhopal   0.01
# 24      indore   0.01
# 25  coimbatore   0.01
# 26     lucknow   0.01
# 27      dallas   0.01
# 28     gwalior   0.00
# 29      panaji   0.00
# 30     belgaum   0.00
# 31   missourie   0.00
# 32      kanpur   0.00
# 33     jodhpur   0.00
# 34  trivandrum   0.00
# 35    varanasi   0.00
# 36      kerala   0.00
# 37      london   0.00
# 38       hubli   0.00
# 39    siliguri   0.00
# 40     seattle   0.00
# 41       kochi   0.00
# 42      nagpur   0.00
# 43       surat   0.00
# 44     udaipur   0.00
# 45       karur   0.00
# 46        agra   0.00
# 47   kozhikode   0.00

# %%
cf[:10]
# Out:
#         City   Fund
# 0  bangalore  45.91
# 1  new delhi  15.36
# 2     mumbai  12.84
# 3    gurgaon  11.28
# 4    unknown   6.93
# 5    chennai   2.24
# 6       pune   2.00
# 7  hyderabad   1.06
# 8      noida   0.93
# 9  ahmedabad   0.54

# %% [markdown]
# ##INVESTMENT TYPE V/S RECIEVING FUNDS

# %%
sf.value_counts("InvestmentType")
# Out:
# InvestmentType
# seed funding      1271
# private equity    1066
# seedfunding         30
# crowd funding        2
# unknown              1
# privateequity        1
# debt funding         1
# dtype: int64

# %%
def correct_spell(s):
    if s=='seedfunding':
        return 'seed funding'
    if s=='privateequity':
        return 'private equity'
    return s
sf["InvestmentType"] = sf["InvestmentType"].apply(correct_spell)

# %%
sf.value_counts("InvestmentType")
it = list(sf.value_counts("InvestmentType").index[:-1])
it
# Out:
# ['seed funding', 'private equity', 'crowd funding', 'unknown']

# %%
i_fund = dict()
for e in it:
    i_fund[e] = sf[sf["InvestmentType"]==e]['AmountInUSD'].sum()
i_fund
# Out:
# {'crowd funding': 155768,
#  'private equity': 18007085000,
#  'seed funding': 332345708,
#  'unknown': 0}

# %%
i_value = list(i_fund.values())
total_fund = sum(i_value)

# %%
itype = list(i_fund.keys())

# %%
i_dict = {'itype':itype,"fund":i_value}
inv_df = pd.DataFrame(i_dict)

# %%
inv_df['fund']=inv_df['fund']*100/total_fund

# %%
inv_df=inv_df.sort_values('fund',ascending=False)

# %%
inv_df.reset_index(drop=True,inplace=True)

# %%
inv_df['fund'] = round(inv_df['fund'],ndigits=2)

# %%
inv_df
# Out:
#             itype   fund
# 0  private equity  98.19
# 1    seed funding   1.81
# 2   crowd funding   0.00
# 3         unknown   0.00

# %%
plt.pie(i_value,labels=itype,radius=3)
plt.legend()
plt.show()

# %% [markdown]
# ##INDUSTRY TYPE V/S RECIEVING FUNDS

# %%
sf.value_counts("IndustryVertical")
# Out:
# IndustryVertical
# consumer internet                    772
# technology                           313
# ecommerce                            230
# unknown                              171
# healthcare                            31
#                                     ...
# online grocery store                   1
# online grocery delivery                1
# online grocers                         1
# online grocer                          1
# 360-degree view creating platform      1
# Length: 729, dtype: int64

# %%
def correct_spell(s):
    if s=='ecommerce':
        return 'Ecommerce'
    return s
sf["IndustryVertical"] = sf["IndustryVertical"].apply(correct_spell)

# %%
sf.value_counts("IndustryVertical")
# Out:
# IndustryVertical
# consumer internet                    772
# technology                           313
# Ecommerce                            230
# unknown                              171
# healthcare                            31
#                                     ...
# online grocery store                   1
# online grocery delivery                1
# online grocers                         1
# online grocer                          1
# 360-degree view creating platform      1
# Length: 729, dtype: int64

# %%
ind_type = list(sf.value_counts("IndustryVertical").index)

# %%
industry_fund = dict()
for e in ind_type:
    industry_fund[e] = sf[sf["IndustryVertical"]==e]["AmountInUSD"].sum()

# %%
tind = list(industry_fund.keys())
ind_val = list(industry_fund.values())
ind_fund = {'industry':tind,'fund':ind_val}
industry_df = pd.DataFrame(ind_fund)

# %%
industry_df.sort_values("fund",ascending=False,inplace=True)

# %%
industry_df.reset_index(drop=True,inplace=True)

# %%
industry_df[:5]
# Out:
#              industry        fund
# 0           Ecommerce  4281189608
# 1   consumer internet  3797089000
# 2             unknown  1231811368
# 3          technology  1103593500
# 4  online marketplace   700000000

# %%
total_fund = sf['AmountInUSD'].sum()

# %%
industry_df['fund'] = round(industry_df['fund']*100/total_fund,ndigits=2)

# %%
industry_df[:10]
# Out:
#                              industry   fund
# 0                           Ecommerce  23.33
# 1                   consumer internet  20.70
# 2                             unknown   6.71
# 3                          technology   6.01
# 4                  online marketplace   3.82
# 5    e-commerce & m-commerce platform   3.71
# 6  car aggregator & retail mobile app   2.73
# 7               ecommerce marketplace   2.73
# 8                      cab aggregator   2.18
# 9               cab rental mobile app   1.23

# %% [markdown]
# ##TOP STARTUPS WITH HIGHEST FUNDINGS

# %%
sf.head()
# Out:
#          Date   StartupName   IndustryVertical  ... AmountInUSD  Remarks  Year
# 0  01/08/2017      touchkin         technology  ...     1300000  unknown  2017
# 1  02/08/2017       ethinos         technology  ...           0  unknown  2017
# 2  02/08/2017  leverage edu  consumer internet  ...           0  unknown  2017
# 3  02/08/2017          zepo  consumer internet  ...      500000  unknown  2017
# 4  02/08/2017  click2clinic  consumer internet  ...      850000  unknown  2017
#
# [5 rows x 10 columns]

# %%
def re_name(s):
    if s[:3]=='ola':
        return 'ola'
    return s

sf["StartupName"]=sf["StartupName"].apply(re_name)

# %%
def re_name(s):
    if s[:3]=='oyo':
        return 'oyo'
    return s

sf["StartupName"]=sf["StartupName"].apply(re_name)

# %%
def re_name(s):
    if s[:5]=='paytm':
        return 'paytm'
    return s

sf["StartupName"]=sf["StartupName"].apply(re_name)

# %%
def re_name(s):
    if s[:8]=='flipkart':
        return 'flipkart'
    return s

sf["StartupName"]=sf["StartupName"].apply(re_name)

# %%
startup_names=list(sf.value_counts("StartupName").index)

# %%
start_up_dict = dict()
for i in startup_names:
    start_up_dict[i] = sf[sf["StartupName"]==i]["AmountInUSD"].sum()

# %%
startup_names = list(start_up_dict.keys())
startup_fund=list(start_up_dict.values())

# %%
sup_dict = {'Startup_name':startup_names,'fund':startup_fund}
startup_df = pd.DataFrame(sup_dict)

# %%
startup_df= startup_df.sort_values('fund',ascending=False).reset_index(drop=True)

# %%
startup_df
# Out:
#      Startup_name        fund
# 0           paytm  2340000000
# 1        flipkart  2259700000
# 2             ola  1899500000
# 3        snapdeal   700000000
# 4             oyo   637000000
# ...           ...         ...
# 1909    trackbizz           0
# 1910      autobix           0
# 1911     athletto           0
# 1912       asocon           0
# 1913      envoged           0
#
# [1914 rows x 2 columns]

# %%
startup_df[:5]
# Out:
#   Startup_name        fund
# 0        paytm  2340000000
# 1     flipkart  2259700000
# 2          ola  1899500000
# 3     snapdeal   700000000
# 4          oyo   637000000

# %% [markdown]
# ##STARTUPS THAT RECIEVED FUNDING MAXIMUM TIMES

# %%
sname = list(sf.value_counts("StartupName").sort_values(ascending=False).index)
stime = list(sf.value_counts("StartupName").sort_values(ascending=False).values)

# %%
for i in range(5):
    print(sname[i],"\t",stime[i])
# Out:
# ola 	 9
# swiggy 	 7
# oyo 	 7
# urbanclap 	 6
# paytm 	 6

# %% [markdown]
# ##TOP INVESTORS FOR STARTUPS

# %%
sf["InvestorsName"]
# Out:
# 0                                             kae capital
# 1                              triton investment advisors
# 2       kashyap deorah, anand sankeshwar, deepak jain,...
# 3       kunal shah, letsventure, anupam mittal, hetal ...
# 4                          narottam thudi, shireesh palle
#                               ...
# 2367                          asia pacific internet group
# 2368                                       karsemven fund
# 2369                       exfinity fund, growx ventures.
# 2370                                           makemytrip
# 2371                    uk based group of angel investors
# Name: InvestorsName, Length: 2372, dtype: object

# %%
l = {'investor_name':[]}
def f(s):
    temp=""
    for i in range(len(s)):
        if(s[i]==','):
            l['investor_name'].append(temp)
            temp=""
            continue
        if(s[i]==" " and (s[i+1]==',' or s[i-1]==',')):
            continue
        temp+=s[i];

sf["InvestorsName"].apply(f)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2367    None
# 2368    None
# 2369    None
# 2370    None
# 2371    None
# Name: InvestorsName, Length: 2372, dtype: object

# %%
investor_name_df = pd.DataFrame(l)

# %%
investor_name_df
# Out:
#                   investor_name
# 0                kashyap deorah
# 1              anand sankeshwar
# 2                   deepak jain
# 3                  sadashiva nt
# 4                   arjun mehta
# ...                         ...
# 2200              goldman sachs
# 2201  inventus capital partners
# 2202          hillhouse capital
# 2203            kalaari capital
# 2204              exfinity fund
#
# [2205 rows x 1 columns]

# %%
investor_name_df.value_counts("investor_name").sort_values(ascending=False)
# Out:
# investor_name
# sequoia capital       40
# accel partners        35
# saif partners         24
# blume ventures        21
# kalaari capital       20
#                       ..
# swan angel network     1
# swapan rajdev          1
# t.v. mohandas pai      1
# vishnu bhat            1
# gaurav dalmia          1
# Length: 1303, dtype: int64

# %%
temp_data = investor_name_df.value_counts("investor_name").sort_values(ascending=False)
name = temp_data.index[0]
time = temp_data.values[0]
name,time
# Out:
# ('sequoia capital', 40)
